# %% [markdown]
# <a href="https://colab.research.google.com/github/tinemyumi/saude-mental-datasus/blob/main/eda-datasets/eda_drs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Relatório**
#
# **Integrantes**
# - Larissa Yumi Tinem
# - Leo Tsuchida Hoçoya
#
# **Conteúdo**
# - Análise Exploratória de Dados sobre a Distribuição Regional de Saúde do Estado de São Paulo
#
# **Histórico de alterações:**
# - 12/11/2025 - Larissa Yumi Tinem - EDA

# %% [markdown]
# # **Análise Exploratória de Dados**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/DadosPopulação/codigos_municipios_regioes.csv', encoding='latin-1', sep=";")

# %% [markdown]
# ### **Verificando as primeiras linhas do DF**

# %%
df.head()
# Out:
#    cod_ibge            municipio    area_km  cod_ra                        ra  \
# 0        35  Estado de São Paulo  248219,48     NaN       Estado de São Paulo
# 3   3500204               Adolfo    211,055     9.0  RA São José do Rio Preto
# 4   3500303                Aguaí    474,554     6.0               RA Campinas
# 5   3500402       Águas da Prata    142,673     6.0               RA Campinas
# 6   3500501     Águas de Lindóia     60,126     6.0               RA Campinas
#
#    cod_rm                        rm  cod_drs                        drs  \
# 0     NaN       Estado de São Paulo      NaN        Estado de São Paulo
# 3     9.0  RM São José do Rio Preto     15.0  DRS São José do Rio Preto
# 4     9.0         Demais municípios     14.0  DRS São João da Boa Vista
# 5     9.0         Demais municípios     14.0  DRS São João da Boa Vista
# 6     9.0         Demais municípios      3.0               DRS Campinas
#
#    cod_r_saude              r_saude
# ...

# %% [markdown]
# ### **Verificando se há valores duplicados**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Verificando se há valores nulos**

# %%
df.isna().sum()
# Out:
# cod_ibge       0
# municipio      0
# area_km        0
# cod_ra         1
# ra             0
# cod_rm         1
# rm             0
# cod_drs        1
# drs            0
# cod_r_saude    1
# r_saude        0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ### **Salvando os dados no drive**

# %%
df.to_csv("/content/drive/MyDrive/Dataframes/cod_regioes.csv")
